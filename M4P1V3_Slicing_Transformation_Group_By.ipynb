# %% [markdown]
# # Data Transformations
# Data transformations adalah perubahan data yang dilakukan untuk kepentingan tertentu seperti menambahkan kolom, merubah tipe data, menghapus sebagaian data, dan lain-lain. Data yang akan digunakan sebagai bahan penjelasan adalah Super-Store-Dataset.csv. Pertama kita import dataset tersebut:

# %%
# Import Modul
import pandas as pd

# %%
df = pd.read_csv('/Super-Store-Dataset_convert.csv - Super-Store-Dataset_convert.csv.csv')
df.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %% [markdown]
# # Menghapus Data

# %%
df_2=df.copy()
df_2.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %% [markdown]
# Untuk melakukan penghapusan data, Pandas memiliki salah atu attribute yang terkait yaitu .drop(). Syntax dari attribute ini adalah sebagai berikut:
# ```
# data.drop(labels=["label_1","label_2","label_3"], # List untuk indeks(baris) yang akan dihapus atau nama kolom
#           axis=1, # 0 untuk menghapus baris dan 1 untuk menghapus kolom
#           inplace=False) #Jika inplace True maka data akan diperbaharui dengan drop
# ```

# %% [markdown]
# **Menghapus Data Kolom**

# %%
df_2_baru=df_2.drop(labels=['order_date','customer_id'],
                    axis=1,
                    inplace=False)
print(df_2.columns)
print(df_2_baru.columns)
# Out:
# Index(['Unnamed: 0', 'order_id', 'order_date', 'customer_id', 'segment',
#        'category', 'sub_category', 'sales', 'quantity', 'profit'],
#       dtype='object')
# Index(['Unnamed: 0', 'order_id', 'segment', 'category', 'sub_category',
#        'sales', 'quantity', 'profit'],
#       dtype='object')

# %% [markdown]
# **Menghapus Data Baris**

# %%
df_2_baru=df_2.drop(labels=[10,20,30,40,50,60],
                    axis=0,
                    inplace=False)
print(df_2.shape)
print(df_2_baru.shape)
# Out:
# (9988, 10)
# (9982, 10)

# %% [markdown]
# # Menambahkan Data Kolom
# Untuk menambahkan kolom baru pada suatu dataframe dapat dilakukan menggunakan syntaxs berikut:
# ```
# data['Nama_Kolom_Baru']=sequece_pengisi_kolom
# ```

# %%
df_2['total_sales'] = df_2['sales']*df_2['quantity']
df_2.head()
# Out:
#    Unnamed: 0        order_id  order_date  ... quantity     profit  total_sales
# 0           0  CA-2016-152156  11/08/2016  ...        2   419136.0       523.92
# 1           1  CA-2016-152156  11/08/2016  ...        3   219582.0      2195.82
# 2           2  CA-2016-138688  06/12/2016  ...        2  2488915.0        29.24
# 3           3  US-2015-108966  10/11/2015  ...        5  -383031.0  47878875.00
# 4           4  US-2015-108966  10/11/2015  ...        2  1192184.0     44736.00
#
# [5 rows x 11 columns]

# %% [markdown]
# # Mengurutkan Data
# Pengurutan dataframe dapat menggunakan attribute .sort_values() dengan syntax berikut:
# ```
# df.sort_values(by='col1',          # Mengurutkan berdasar kolom tertentu
#                ascending=False)    # Menaik(ascending=True) atau menurun(ascending=False)
# ```

# %%
df_2_urut=df_2.sort_values(by='segment',
                           ascending=True)
df_2_urut
# Out:
#       Unnamed: 0        order_id  order_date  ... quantity     profit total_sales
# 0              0  CA-2016-152156  11/08/2016  ...        2   419136.0      523.92
# 5505        5505  CA-2015-168529  10/08/2015  ...        5    62737.0      729.50
# 5504        5504  CA-2016-150000  04/08/2016  ...        4  1503553.0       71.68
# 5503        5503  US-2016-162026  10/08/2016  ...        2    27882.0      123.92
# 5498        5498  CA-2017-164378   7/15/2017  ...        2   732038.0       17.92
# ...          ...             ...         ...  ...      ...        ...         ...
# 6051        6051  CA-2016-124016   9/23/2016  ...        7   -97608.0    85407.00
# 6050        6050  CA-2016-124016   9/23/2016  ...        4    44384.0      112.00
# 6049        6049  CA-2016-124016   9/23/2016  ...        3  -570417.0    35856.00
# 699          699  CA-2015-119291   5/14/2015  ...        2  -136312.0    37176.00
# 6714        6714  CA-2016-134789  04/08/2016  ...        4  1865995.0      103.68
#
# [9988 rows x 11 columns]

# %%
df_2_urut=df_2.sort_values(by=['segment','category'],
                           ascending=True)
df_2_urut
# Out:
#       Unnamed: 0        order_id  order_date  ... quantity     profit  total_sales
# 0              0  CA-2016-152156  11/08/2016  ...        2  419136.00       523.92
# 1              1  CA-2016-152156  11/08/2016  ...        3  219582.00      2195.82
# 3              3  US-2015-108966  10/11/2015  ...        5 -383031.00  47878875.00
# 5              5  CA-2014-115812  06/09/2014  ...        7  141694.00       342.02
# 10            10  CA-2014-115812  06/09/2014  ...        9  853092.00  15355656.00
# ...          ...             ...         ...  ...      ...        ...          ...
# 9858        9858  CA-2017-113278   1/14/2017  ...        4   70312.00       639.20
# 9872        9872  US-2017-166324   4/20/2017  ...        3 -244764.00    367146.00
# 9954        9954  CA-2017-141446   9/16/2017  ...        1       3.24        18.00
# 9967        9967  US-2016-103674  12/06/2016  ...        5   27196.00      1359.80
# 9970        9970  US-2016-103674  12/06/2016  ...        2   31198.00    499168.00
#
# [9988 rows x 11 columns]

# %% [markdown]
# # Mengubah Nama Kolom
# Kita dapat merubah nama kolom pada dataframe dengan cara seperti pada contoh berikut:

# %%
df.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %%
# Mengganti nama kolom "profit" menjadi "keuntungan"
df2 = df.rename(columns={"profit":"keuntungan"})
df2.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity keuntungan
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %% [markdown]
# # Indexing DataFrame

# %% [markdown]
# Index merupakan key identifier dari tiap row/column untuk Series atau Dataframe (sifatnya tidak mutable untuk masing-masing value tapi bisa diganti untuk semua value sekaligus).
#
# Jika tidak disediakan, pandas akan membuat kolom index default secara otomatis sebagai bilangan bulat (integer) dari 0 sampai range jumlah baris data tersebut.
#
# Kolom index dapat terdiri dari
#
# 1.  satu kolom (single index), atau
# 2.  multiple kolom (disebut dengan hierarchical indexing).
#
# Index dengan multiple kolom ini terjadi karena unique identifier tidak dapat dicapai hanya dengan set index di 1 kolom saja sehingga membutuhkan beberapa kolom yang menjadikan tiap row menjadi unique.

# %% [markdown]
# # Single Index

# %%
df_super_store = pd.read_csv('/Super-Store-Dataset_convert.csv - Super-Store-Dataset_convert.csv.csv')

# %%
df_super_store.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %%
print("Index:", df_super_store.index)

print("Columns:", df_super_store.columns)
# Out:
# Index: RangeIndex(start=0, stop=9988, step=1)
# Columns: Index(['Unnamed: 0', 'order_id', 'order_date', 'customer_id', 'segment',
#        'category', 'sub_category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %% [markdown]
# # Multiple Index
# Kita akan coba tunjukkan bagaimana caranya membuat sebuah dataframe dengan multi index

# %%
df_super_store.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %%
# Set multi index df
df_ss = df_super_store.set_index(['order_id', 'order_date', 'customer_id'])
# Print nama dan level dari multi index
for name, level in zip(df_ss.index.names, df_ss.index.levels):
    print(name,':',level)
# Out:
# order_id : Index(['CA-2014-100006', 'CA-2014-100090', 'CA-2014-100293', 'CA-2014-100328',
#        'CA-2014-100363', 'CA-2014-100391', 'CA-2014-100678', 'CA-2014-100706',
#        'CA-2014-100762', 'CA-2014-100860',
#        ...
#        'US-2017-167570', 'US-2017-167920', 'US-2017-168116', 'US-2017-168613',
#        'US-2017-168690', 'US-2017-168802', 'US-2017-169320', 'US-2017-169488',
#        'US-2017-169502', 'US-2017-169551'],
#       dtype='object', name='order_id', length=5008)
# order_date : Index(['01/01/2017', '01/02/2015', '01/02/2016', '01/02/2017', '01/03/2014',
#        '01/03/2015', '01/03/2016', '01/03/2017', '01/04/2014', '01/04/2015',
#        ...
#        '9/28/2014', '9/28/2015', '9/28/2016', '9/28/2017', '9/29/2014',
#        '9/29/2016', '9/29/2017', '9/30/2014', '9/30/2016', '9/30/2017'],
#       dtype='object', name='order_date', length=1237)
# customer_id : Index(['AA-10315', 'AA-10375', 'AA-10480', 'AA-10645', 'AB-10015', 'AB-10060',
#        'AB-10105', 'AB-10150', 'AB-10165', 'AB-10255',
#        ...
#        'VP-21760', 'VS-21820', 'VT-21700', 'VW-21775', 'WB-21850', 'XP-21865',
#        'YC-21895', 'YS-21880', 'ZC-21910', 'ZD-21925'],
#       dtype='object', name='customer_id', length=793)

# %% [markdown]
# # Latihan 1
# Buatlah multiple index pada df_super_store menggunakan kolom order_id dan customer_id

# %%
# Set multi index df
df_ss = df_super_store.set_index(['order_id','customer_id'])

# Print nama dan level dari multi index
for name, level in zip(df_ss.index.names, df_ss.index.levels):
    print(name,':',level)
# Out:
# order_id : Index(['CA-2014-100006', 'CA-2014-100090', 'CA-2014-100293', 'CA-2014-100328',
#        'CA-2014-100363', 'CA-2014-100391', 'CA-2014-100678', 'CA-2014-100706',
#        'CA-2014-100762', 'CA-2014-100860',
#        ...
#        'US-2017-167570', 'US-2017-167920', 'US-2017-168116', 'US-2017-168613',
#        'US-2017-168690', 'US-2017-168802', 'US-2017-169320', 'US-2017-169488',
#        'US-2017-169502', 'US-2017-169551'],
#       dtype='object', name='order_id', length=5008)
# customer_id : Index(['AA-10315', 'AA-10375', 'AA-10480', 'AA-10645', 'AB-10015', 'AB-10060',
#        'AB-10105', 'AB-10150', 'AB-10165', 'AB-10255',
#        ...
#        'VP-21760', 'VS-21820', 'VT-21700', 'VW-21775', 'WB-21850', 'XP-21865',
#        'YC-21895', 'YS-21880', 'ZC-21910', 'ZD-21925'],
#       dtype='object', name='customer_id', length=793)

# %% [markdown]
# # Slicing DataFrrame

# %% [markdown]
# # Slicing berdasarkan data kolom

# %%
df_super_store.order_date
# Out:
# 0       11/08/2016
# 1       11/08/2016
# 2       06/12/2016
# 3       10/11/2015
# 4       10/11/2015
#            ...
# 9983     1/21/2014
# 9984     2/26/2017
# 9985     2/26/2017
# 9986     2/26/2017
# 9987    05/04/2017
# Name: order_date, Length: 9988, dtype: object

# %%
df_super_store['order_date']
# Out:
# 0       11/08/2016
# 1       11/08/2016
# 2       06/12/2016
# 3       10/11/2015
# 4       10/11/2015
#            ...
# 9983     1/21/2014
# 9984     2/26/2017
# 9985     2/26/2017
# 9986     2/26/2017
# 9987    05/04/2017
# Name: order_date, Length: 9988, dtype: object

# %% [markdown]
# Kita juga dapat mengakses beberapa kolom dataframe menggunakan list nama-nama kolom yang kita inginkan sebagai berikut:

# %%
df_ss1=df_super_store[['order_id','customer_id']]
df_ss1
# Out:
#             order_id customer_id
# 0     CA-2016-152156    CG-12520
# 1     CA-2016-152156    CG-12520
# 2     CA-2016-138688    DV-13045
# 3     US-2015-108966    SO-20335
# 4     US-2015-108966    SO-20335
# ...              ...         ...
# 9983  CA-2014-110422    TB-21400
# 9984  CA-2017-121258    DB-13060
# 9985  CA-2017-121258    DB-13060
# 9986  CA-2017-121258    DB-13060
# 9987  CA-2017-119914    CC-12220
#
# [9988 rows x 2 columns]

# %% [markdown]
# # Slicing Berdasarkan Baris

# %%
# Mengakses 5 baris data teratas
df_super_store[:5]
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %%
# Mengakses data dari baris 0 hingga baris sebelum 6
df_super_store[3:6]
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
# 5           5  CA-2014-115812  06/09/2014  ...       48.86        7   141694.0
#
# [3 rows x 10 columns]

# %%
# Mengakses 5 baris data terakhir
df_super_store[-5:]
# Out:
#       Unnamed: 0        order_id  order_date  ...      sales quantity     profit
# 9983        9983  CA-2014-110422   1/21/2014  ...   25248.00        3 -318399.00
# 9984        9984  CA-2017-121258   2/26/2017  ...      91.96        2  156332.00
# 9985        9985  CA-2017-121258   2/26/2017  ...  258576.00        2  193932.00
# 9986        9986  CA-2017-121258   2/26/2017  ...   44376.00        4      13.32
# 9987        9987  CA-2017-119914  05/04/2017  ...     243.16        2   72948.00
#
# [5 rows x 10 columns]

# %% [markdown]
# # Slicing menggunakan attribute .iloc

# %% [markdown]
# Kita dapat melakukan slicing berdasarkan baris & kolom menggunakan attribut .iloc:

# %%
# Mengakses 10 baris pertama kolom 2 dan 3
df_super_store.iloc[:10,1:3]
# Out:
#          order_id  order_date
# 0  CA-2016-152156  11/08/2016
# 1  CA-2016-152156  11/08/2016
# 2  CA-2016-138688  06/12/2016
# 3  US-2015-108966  10/11/2015
# 4  US-2015-108966  10/11/2015
# 5  CA-2014-115812  06/09/2014
# 6  CA-2014-115812  06/09/2014
# 7  CA-2014-115812  06/09/2014
# 8  CA-2014-115812  06/09/2014
# 9  CA-2014-115812  06/09/2014

# %%
# Mengakses semua baris pada kolom 2 dan 3
df_super_store.iloc[:,1:3]
# Out:
#             order_id  order_date
# 0     CA-2016-152156  11/08/2016
# 1     CA-2016-152156  11/08/2016
# 2     CA-2016-138688  06/12/2016
# 3     US-2015-108966  10/11/2015
# 4     US-2015-108966  10/11/2015
# ...              ...         ...
# 9983  CA-2014-110422   1/21/2014
# 9984  CA-2017-121258   2/26/2017
# 9985  CA-2017-121258   2/26/2017
# 9986  CA-2017-121258   2/26/2017
# 9987  CA-2017-119914  05/04/2017
#
# [9988 rows x 2 columns]

# %%
# Mengakses 5 baris data pertama semua kolom
df_super_store.iloc[:5,:]
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %% [markdown]
# # Slicing Dengan Kriteria

# %% [markdown]
# Melakukan filter berdasarkan kriteria tertentu adalah hal yang paling sering dilakukan oleh seorang data analis atau data saintis. Berikut adalah beberapa contoh filtering menggunakan pandas.

# %%
# Mengambil data dari df__sperstore dengan sentimen positif
df_1=df_super_store[df_super_store['category']=="Furniture"]
df_1
# Out:
#       Unnamed: 0        order_id  order_date  ...       sales quantity    profit
# 0              0  CA-2016-152156  11/08/2016  ...      261.96        2  419136.0
# 1              1  CA-2016-152156  11/08/2016  ...      731.94        3  219582.0
# 3              3  US-2015-108966  10/11/2015  ...  9575775.00        5 -383031.0
# 5              5  CA-2014-115812  06/09/2014  ...       48.86        7  141694.0
# 10            10  CA-2014-115812  06/09/2014  ...  1706184.00        9  853092.0
# ...          ...             ...         ...  ...         ...      ...       ...
# 9956        9956  CA-2015-168088   3/19/2015  ...  3834656.00        4 -676704.0
# 9958        9958  CA-2016-146374  12/05/2016  ...    44299.00        1    6432.0
# 9974        9974  US-2015-151435  09/06/2015  ...       85.98        1  223548.0
# 9983        9983  CA-2014-110422   1/21/2014  ...    25248.00        3 -318399.0
# 9984        9984  CA-2017-121258   2/26/2017  ...       91.96        2  156332.0
#
# [2121 rows x 10 columns]

# %%
# mengambil data dengan lebih dari 1 kriteria
df_2=df_super_store[(df_super_store['category']=="Furniture") & (df_super_store['quantity']>=3)]
df_2
# Out:
#       Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 1              1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 3              3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 5              5  CA-2014-115812  06/09/2014  ...       48.86        7   141694.0
# 10            10  CA-2014-115812  06/09/2014  ...  1706184.00        9   853092.0
# 24            24  CA-2015-106320   9/25/2015  ...     1044.63        3  2402649.0
# ...          ...             ...         ...  ...         ...      ...        ...
# 9925        9925  CA-2015-104948  11/13/2015  ...   683332.00        4   -40196.0
# 9932        9932  CA-2016-169824  12/12/2016  ...       60.35        5   199155.0
# 9941        9941  CA-2017-121559  06/01/2017  ...     1925.88        6  5392464.0
# 9956        9956  CA-2015-168088   3/19/2015  ...  3834656.00        4  -676704.0
# 9983        9983  CA-2014-110422   1/21/2014  ...    25248.00        3  -318399.0
#
# [1425 rows x 10 columns]

# %%
# mengambil data dengan karakter tertentu (customer_id mengandung CG)
df_3=df_super_store[df_super_store.customer_id.str.contains('CG')]
df_3
# Out:
#       Unnamed: 0        order_id  order_date  ...      sales quantity     profit
# 0              0  CA-2016-152156  11/08/2016  ...     261.96        2   419136.0
# 1              1  CA-2016-152156  11/08/2016  ...     731.94        3   219582.0
# 933          933  CA-2016-140081   6/20/2016  ...   45056.00        8   152064.0
# 934          934  CA-2016-140081   6/20/2016  ...   29718.00        6  -217932.0
# 935          935  CA-2016-140081   6/20/2016  ...   15552.00        3   924917.0
# 936          936  CA-2016-140081   6/20/2016  ...  447696.00        2   335772.0
# 1476        1476  US-2017-104955   3/19/2017  ...      28.91        7   132986.0
# 2205        2205  CA-2016-164350  09/10/2016  ...      67.56        3     8445.0
# 5075        5075  CA-2017-143217  11/11/2017  ...      18.24        3  1398363.0
# 5488        5488  CA-2017-164098   1/26/2017  ...      18.16        2     1816.0
# 6283        6283  CA-2016-121020  10/24/2016  ...  239976.00        3   179982.0
# 6873        6873  US-2015-123918  10/15/2015  ...  131376.00        6  -952476.0
# 6874        6874  US-2015-123918  10/15/2015  ...    5344.00        1  2485111.0
# 9558        9558  CA-2015-161242  06/01/2015  ...      11.76        2  2090771.0
#
# [14 rows x 10 columns]

# %% [markdown]
# # Summarize DataFrame

# %% [markdown]
# Untuk melihat nilai-nilai statistik seperti mean, min, max dll dapat dilakukan untuk masing-masing kolom sebagai berikut:

# %%
# Menghitung rata-rata variabel petal_length
df_super_store.quantity.mean()
# Out:
# 3.789146976371646

# %%
# Menghitung nilai minimum variabel petal_length
df_super_store.quantity.min()
# Out:
# 1

# %%
# Menghitung nilai maximum variabel petal_length
df_super_store.profit.max()
# Out:
# 46304755.0

# %%
# Menghitung nilai jumlahan variabel petal_length
df_super_store.profit.sum()
# Out:
# 4437162942.440001

# %% [markdown]
# Fungsi Deskripsi:
# ```
#  mean()    #Hitung rata-rata sequence
#  sum()     #Hitung jumlah nilai sequence
#  size()    #Hitung ukuran sequence
#  count()   #Hitung jumlah sequence
#  std()     #Standar deviasi sequence
#  var()     #Hitung varians sequence
#  sem ()    #Kesalahan standar rata-rata sequence
#  min ()    #Hitung minimum nilai grup
#  max ()    #Hitung maks nilai grup
#  ```

# %% [markdown]
# # Aggregation & GroupBy

# %% [markdown]
# Groupby memiliki konsep untuk
#
# 1.  **Split**: melakukan indexing/multi-indexing dengan apa yang di specify as groupby menjadi kelompok
# 2.  **Apply**: menerapkan fungsi pada masing-masing kelompok tersebut
# 3.  **Combine**: mengumpulkan semua hasil fungsi dari tiap kelompok kembali menjadi dataframe

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dataset

# %%
df = df_super_store
df.head()
# Out:
#    Unnamed: 0        order_id  order_date  ...       sales quantity     profit
# 0           0  CA-2016-152156  11/08/2016  ...      261.96        2   419136.0
# 1           1  CA-2016-152156  11/08/2016  ...      731.94        3   219582.0
# 2           2  CA-2016-138688  06/12/2016  ...       14.62        2  2488915.0
# 3           3  US-2015-108966  10/11/2015  ...  9575775.00        5  -383031.0
# 4           4  US-2015-108966  10/11/2015  ...    22368.00        2  1192184.0
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9988 entries, 0 to 9987
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9988 non-null   int64
#  1   order_id      9988 non-null   object
#  2   order_date    9988 non-null   object
#  3   customer_id   9988 non-null   object
#  4   segment       9988 non-null   object
#  5   category      9988 non-null   object
#  6   sub_category  9988 non-null   object
#  7   sales         9988 non-null   float64
#  8   quantity      9988 non-null   int64
#  9   profit        9988 non-null   float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 780.4+ KB

# %% [markdown]
# # GroupBy Satu Variabel dengan Satu Fungsi Aggregat

# %% [markdown]
# Kita dapat melakukan groupby terhadap satu buah variabel(contoh: category) dengan menggunakan sebuah fungsi aggregat(mean).

# %%
#Groupby berdasarkan variabel 'category', fungsi aggregat `mean`
hasil_group_by=df.groupby('category').mean() 
hasil_group_by
# Out:
#                   Unnamed: 0          sales  quantity         profit
# category
# Furniture        5037.842999  245173.239231  3.785007  221809.604121
# Office Supplies  4976.415201   37526.415490  3.801195  476861.213774
# Technology       4998.335144  144381.232662  3.754481  593774.632211

# %%
#Groupby berdasarkan variabel 'category', fungsi aggregat `mean`
hasil_group_by=df.groupby('category')[['sales','profit']].mean() 
hasil_group_by
# Out:
#                          sales         profit
# category
# Furniture        245173.239231  221809.604121
# Office Supplies   37526.415490  476861.213774
# Technology       144381.232662  593774.632211

# %% [markdown]
# # GroupBy Multivariabel dengan Satu Fungsi Aggregat

# %% [markdown]
# Untuk menampung banyak fungsi agregat, atau ketika kita menginginkan fungsi agregat yang berbeda-beda pada masing-masing variabel, kita dapat menuliskannya dalam sebuah dictionary sebagai berikut:

# %%
import numpy as np

# %%
sub_category=df.groupby(['category'])[['sales','quantity','profit']].agg({
    'sales':min,
    'quantity':max,
    'profit':np.mean
})
sub_category
# Out:
#                     sales  quantity         profit
# category
# Furniture       -310788.0        14  221809.604121
# Office Supplies -328685.0        14  476861.213774
# Technology      -315721.0        14  593774.632211

# %% [markdown]
# # GroupBy dengan Fungsi Aggregat Custom

# %%
def data_range(series):
  return series.max() - series.min()

sub_category=df.groupby(['sub_category','category'])[['sales','quantity','profit']].agg(data_range)
sub_category
# Out:
#                                     sales  quantity      profit
# sub_category category
# Accessories  Technology        1692381.00        13   9049712.0
# Appliances   Office Supplies   1256678.00        13  19330425.0
# Art          Office Supplies   1113022.36        13   3588265.0
# Binders      Office Supplies   4535974.56        13  83323683.0
# Bookcases    Furniture        23962620.51        12  20721810.0
# Chairs       Furniture         4723007.00        13  10049094.0
# Copiers      Technology        8399676.01         8  25859570.0
# Envelopes    Office Supplies    604651.28         8   3301520.0
# Fasteners    Office Supplies     58366.76        13   3423815.0
# Furnishings  Furniture         1318020.00        13   7361970.0
# Labels       Office Supplies    629181.48        13   4464620.0
# Machines     Technology        8475673.00        10  62409561.0
# Paper        Office Supplies    360708.62        13   3602082.0
# Phones       Technology        4654885.00        13  16145703.0
# Storage      Office Supplies   2130317.00        13   9650019.0
# Supplies     Office Supplies   4663733.08         9  13449194.0
# Tables       Furniture         9743360.00        12  24731748.0

# %% [markdown]
# # Latihan 2

# %% [markdown]
# Diberikan dataset retail berikut: Super-Store-Dataset.csv :
#
# 1.  Tentukan Segment mana dengan profit tertinggi!
# 2.  Tentukan Category mana dengan sales terbanyak!
# 3.  Tentukan Sub-Category dengan quantity paling sedikit!
# 4.  Lakukanlah 3 contoh filter munggunakan 2 kriteria!
# 5.  Lakukanlah 3 contoh filter menggunakan attributes str.contains!

# %% [markdown]
# # 1.  Tentukan Segment mana dengan profit tertinggi?

# %%
segment_profit_tertinggi=df.groupby('segment')[['profit']].max() 
segment_profit_tertinggi
# Out:
#                  profit
# segment
# Consumer     46304755.0
# Corporate    23659818.0
# Home Office  25919568.0

# %% [markdown]
# # 2.  Tentukan Category mana dengan sales terbanyak!

# %%
Category_sales_terbanyak = df.groupby('category')[['sales']].max()
Category_sales_terbanyak
# Out:
#                       sales
# category
# Furniture        23962656.0
# Office Supplies   4663736.0
# Technology        8399976.0

# %% [markdown]
# # 3.  Tentukan Sub_Category dengan quantity paling sedikit!

# %%
Sub_Category_quantity_sedikit = df.groupby('sub_category')[['quantity']].min()
Sub_Category_quantity_sedikit
# Out:
#               quantity
# sub_category
# Accessories          1
# Appliances           1
# Art                  1
# Binders              1
# Bookcases            1
# Chairs               1
# Copiers              1
# Envelopes            1
# Fasteners            1
# Furnishings          1
# Labels               1
# Machines             1
# Paper                1
# Phones               1
# Storage              1
# Supplies             1
# Tables               1

# %% [markdown]
# # 4.  Lakukanlah 3 contoh filter munggunakan 2 kriteria!

# %%
# filter menggunakan 2 kriteria
df_2=df_super_store[(df_super_store['category']=="Office Supplies") & (df_super_store['quantity']>=10)]
df_2
# Out:
#             order_id  order_date customer_id  ...    sales quantity     profit
# 113   CA-2014-115259   8/25/2014    RC-19960  ...   40.096       14    145.348
# 329   US-2016-141544   8/30/2016    PO-18850  ...   100.24       10     33.831
# 341   CA-2014-122336   4/13/2014    JD-15895  ...   509.97       10   -407.976
# 342   CA-2014-122336   4/13/2014    JD-15895  ...   30.992       13    10.0724
# 575   CA-2015-149713   9/18/2015    TG-21640  ...   160.72       14    787.528
# ...              ...         ...         ...  ...      ...      ...        ...
# 9686  CA-2015-107902   8/28/2015    SM-20950  ...   470.36       11  1.222.936
# 9717  CA-2014-101364  12/22/2014    TW-21025  ...  296.712       13  1.001.403
# 9814  CA-2015-162201    6/8/2015    AG-10495  ...    42.24       10       13.2
# 9973  US-2016-103674   12/6/2016    AP-10720  ...  437.472       14  1.531.152
# 9978  CA-2015-100251   5/17/2015    DV-13465  ...     31.5       10      15.12
#
# [96 rows x 9 columns]

# %%
# filter menggunakan 2 kriteria
df_2=df_super_store[(df_super_store['segment']=="Home Office") & (df_super_store['sub_category']=="Labels")]
df_2
# Out:
#             order_id  order_date customer_id  ...   sales quantity   profit
# 290   CA-2016-110772  11/20/2016    NZ-18565  ...  18.496        8   6.2424
# 484   CA-2017-140963   6/10/2017    MT-18070  ...    29.6        2     14.8
# 695   CA-2015-119291   5/14/2015    JO-15550  ...   47.36        4    17.76
# 697   CA-2015-119291   5/14/2015    JO-15550  ...  97.696        4  317.512
# 739   CA-2014-112326    1/4/2014    PO-19195  ...  11.784        3   4.2717
# ...              ...         ...         ...  ...     ...      ...      ...
# 8854  CA-2015-125934   9/11/2015    SN-20560  ...   31.05        3   14.904
# 8898  US-2016-126431    7/1/2016    SU-20665  ...   30.53        1  140.438
# 9113  US-2016-155971    6/6/2016    RB-19795  ...   22.05        7   10.584
# 9425  CA-2015-111864   6/19/2015    PP-18955  ...   5.904        2   1.9926
# 9442  US-2016-148957   9/17/2016    CC-12430  ...   12.32        4   5.9136
#
# [73 rows x 9 columns]

# %%
# filter menggunakan 2 kriteria
df_2=df_super_store[(df_super_store['order_id']=="CA-2015-119291") & (df_super_store['sub_category']=="Binders")]
df_2
# Out:
#            order_id order_date customer_id  ...   sales quantity    profit
# 699  CA-2015-119291  5/14/2015    JO-15550  ...  18.588        2  -136.312
# 700  CA-2015-119291  5/14/2015    JO-15550  ...   4.896        3   -34.272
#
# [2 rows x 9 columns]

# %% [markdown]
# # 5.  Lakukanlah 3 contoh filter menggunakan attributes str.contains!

# %%
df_3=df_super_store[df_super_store.customer_id.str.contains('JO')]
df_3

# %%
df_3=df_super_store[df_super_store.order_id.str.contains('US')]
df_3

# %%
df_3=df_super_store[df_super_store.order_id.str.contains('CA')]
df_3
